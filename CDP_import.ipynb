# %%
# %matplotlib inline

# %%
import pandas as pd

from flask import *
from __init__ import app

from flask.ext.sqlalchemy import SQLAlchemy
from apps.glyph.models import *

app.testing = True
client = app.test_client()
ctx = app.test_request_context()
ctx.push()

# %%
# do we need a numerical index?
df = pd.DataFrame.from_csv("csvs/cdp_signs_modified.csv")
# replace NaN with None
signs = df.where((pd.notnull(df)), None)

# %%
signs.head()
# Out:
#       CDP SIGN REF NAME Description ORACC sign CDLI archaic variant_name  \
# index
# 1                     1        None       None         None         None
# 2                     1        None       None         None         None
# 3                     1        None       None         None         None
# 4                     1        None       None         None         None
# 5                     1        None       None         None         None
#
#       form_description notes MesZL ELLes  ZATU  ...    RSP  Emar  \
# index                                           ...
# 1                 None  None     1  None  None  ...   None  None
# 2                 None  None   748  None  None  ...      3  None
# 3                 None  None   748  None  None  ...      5  None
# 4                 None  None   748  None  None  ...     24  None
# 5                 None  None   748  None  None  ...     25  None
#
# ...

# %%
# Add unique CDP Signs as Sign instances
uniq = list(set(list(signs['CDP SIGN REF NAME'].dropna())))
new_signs = []
for each in uniq:
    s = Sign(sign_ref=each)
    new_signs.append(s)
db.session.add_all(new_signs)
db.session.commit()

# %%
# Add unique Descriptions
uniq = list(set(list(signs['Description'].dropna())))
new_descr = []
for each in uniq:
    s = Description(sign_ref=each)
    new_descr.append(s)
db.session.add_all(new_descr)
db.session.commit()

# %%
# Add unique Oracc Descriptions
uniq = list(set(list(signs['ORACC sign'].dropna())))
new_oracc = []
for each in uniq:
    s = Oracc(sign_ref=each)
    new_oracc.append(s)
db.session.add_all(new_oracc)
db.session.commit()

# %%
# Add unique CDLI Archaic
uniq = list(set(list(signs['CDLI archaic'].dropna())))
new_cdli = []
for each in uniq:
    s = Cdli(sign_ref=each)
    new_cdli.append(s)
db.session.add_all(new_cdli)
db.session.commit()

# %%
# Fix missing 'NA' values (record 3225-8 in import CSV)
# repeat for NA~a ~b ~c ~d
for s in ['NA~a', 'NA~b', 'NA~c', 'NA~d']:
    signs.ix[df['CDLI archaic'] == s, 'CDP SIGN REF NAME'] = 'NA'
    signs.ix[df['CDLI archaic'] == s, 'ORACC sign'] = 'NA'
    signs.ix[df['CDLI archaic'] == s, 'Description'] = 'NA'

# %%
to_add = list()

fields = [
    "variant_name",
    "form_description",
    "notes",
    "MesZL",
    "ELLes",
    "ZATU",
    "LAK",
    "UET_2",
    "ARM_XV",
    "Hinke",
    "Clay_BE_A_14",
    "Koenig_AfO_Bei_16",
    "Ranke_BE_A_61",
    "Schroeder_VS_12",
    "Clay_BE_A_10",
    "RSP",
    "Emar",
    "Schroder_VS_15",
    "HZL",
    "HA",
    "aBZL",
    "REC",
    "Labat",
    "KWU",
    "Fossey_pp",
]

for i, record in signs.iterrows():
    dict_record = dict(record)
    d = dict()
#     if dict_record.get('CDP SIGN REF NAME'):
    d['sign'] = Sign.query.filter_by(sign_ref=dict_record.get('CDP SIGN REF NAME').strip()).one()
    if dict_record.get('Description'):
        d['description'] = Description.query.filter_by(sign_ref=dict_record.get('Description').strip()).one()
    if dict_record.get('ORACC sign'):
        d['oracc'] = Oracc.query.filter_by(sign_ref=dict_record.get('ORACC sign').strip()).one()
    if dict_record.get('CDLI archaic'):
        d['cdli'] = Cdli.query.filter_by(sign_ref=dict_record.get('CDLI archaic').strip()).one()
    for f in fields:
        d[f] = dict_record.get(f)
    to_add.append(Cdp(**d))

# %%
db.session.add_all(to_add)
db.session.commit()
